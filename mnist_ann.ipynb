# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Aug 1 13 12:27:50 2023

@author: PRATISTHA
"""

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
import os

num_classes = 10
input_shape = (28, 28, 1)

# Get the working directory path
current_dir = os.getcwd()

# Load the MNIST dataset and normalize the pixel values
(x_train, y_train), (x_test, y_test) = mnist.load_data(path=current_dir + '/mnist.zip')
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))  # Increased complexity with 128 neurons
model.add(Dropout(0.5))  # Dropout for regularization
model.add(Dense(64, activation='relu'))   # Another hidden layer with 64 neurons
model.add(Dropout(0.5))  # Dropout for regularization
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=20, batch_size=128, validation_data=(x_test, y_test))

# Evaluate the model on the test data
_, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_accuracy}')
# Out:
# Epoch 1/20
# 469/469 [==============================] - 5s 8ms/step - loss: 0.7400 - accuracy: 0.7702 - val_loss: 0.2252 - val_accuracy: 0.9332
# Epoch 2/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3660 - accuracy: 0.8966 - val_loss: 0.1666 - val_accuracy: 0.9514
# Epoch 3/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2957 - accuracy: 0.9172 - val_loss: 0.1417 - val_accuracy: 0.9586
# Epoch 4/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2533 - accuracy: 0.9302 - val_loss: 0.1358 - val_accuracy: 0.9623
# Epoch 5/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2290 - accuracy: 0.9368 - val_loss: 0.1217 - val_accuracy: 0.9641
# Epoch 6/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2136 - accuracy: 0.9415 - val_loss: 0.1198 - val_accuracy: 0.9677
# Epoch 7/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2029 - accuracy: 0.9441 - val_loss: 0.1087 - val_accuracy: 0.9691
# Epoch 8/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1938 - accuracy: 0.9466 - val_loss: 0.1045 - val_accuracy: 0.9684
# Epoch 9/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1811 - accuracy: 0.9483 - val_loss: 0.1022 - val_accuracy: 0.9703
# Epoch 10/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1766 - accuracy: 0.9506 - val_loss: 0.1032 - val_accuracy: 0.9705
# Epoch 11/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1707 - accuracy: 0.9519 - val_loss: 0.0986 - val_accuracy: 0.9712
# Epoch 12/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1642 - accuracy: 0.9531 - val_loss: 0.0974 - val_accuracy: 0.9725
# Epoch 13/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1585 - accuracy: 0.9542 - val_loss: 0.0934 - val_accuracy: 0.9723
# Epoch 14/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1544 - accuracy: 0.9556 - val_loss: 0.0929 - val_accuracy: 0.9748
# Epoch 15/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1477 - accuracy: 0.9571 - val_loss: 0.0943 - val_accuracy: 0.9735
# Epoch 16/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1434 - accuracy: 0.9582 - val_loss: 0.0951 - val_accuracy: 0.9722
# Epoch 17/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1430 - accuracy: 0.9591 - val_loss: 0.0931 - val_accuracy: 0.9740
# Epoch 18/20
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1416 - accuracy: 0.9598 - val_loss: 0.0860 - val_accuracy: 0.9745
# Epoch 19/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1428 - accuracy: 0.9599 - val_loss: 0.0900 - val_accuracy: 0.9755
# Epoch 20/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1376 - accuracy: 0.9597 - val_loss: 0.0883 - val_accuracy: 0.9758
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0883 - accuracy: 0.9758
# Test accuracy: 0.9757999777793884
